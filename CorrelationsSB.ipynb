# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
# %matplotlib inline

# %%
df = pd.read_csv('finaldata_sb.csv')
df.head()
# Out:
#      ZIP  yearlyChange_SmallBuss10_13  NumberSB(total)2013(normbypop)  \
# 0  11430                        -0.02                            0.02
# 1  10162                         0.03                            0.00
# 2  11005                         0.01                            0.01
# 3  10004                         0.02                            0.30
# 4  10006                         0.01                            0.37
#
#    Change_Rent_2009_2015  Animal Abuse  \
# 0                   0.02      0.000000
# 1                   0.02      0.000000
# 2                  -0.01      0.000000
# 3                   0.02      0.000452
# 4                   0.02      0.001446
#
#    Blocked Driveway/Traffic/Illegal Parking  Derelict Vehicle  \
# 0                                  0.001426          0.000178
# 1                                  0.000083          0.000000
# 2                                  0.000198          0.000198
# ...

# %%
# Create new dataframe for each type of housing complaint and then do the correlation test

pr = scipy.stats.pearsonr(df['yearlyChange_SmallBuss10_13'], df['Change_Rent_2009_2015'])
pr1 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Change_Rent_2009_2015'])
pr2 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Animal Abuse'])
pr3 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Blocked Driveway/Traffic/Illegal Parking'])
pr4 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Derelict Vehicle'])
pr5 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Disorderly Youth/Graffiti/BikeRoller_SkateChronic'])
pr6 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Derelict Vehicle'])
pr7 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Drinking'])
pr8 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Illegal Fireworks'])
pr9 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Noise'])
pr10 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Panhandling/Homeless Encampment'])
pr11 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Vending'])
pr12 = scipy.stats.pearsonr(df['NumberSB(total)2013(normbypop)'], df['Totalsum'])

# %%
correlations = [pr,pr1, 
pr2, 
pr3, 
pr4,
pr5, 
pr6,
pr7, 
pr8,
pr9, 
pr10, 
pr11, 
pr12]
correlations
# Out:
# [(0.15293198782260661, 0.040405827658371418),
#  (0.038764059836015947, 0.60540367078614676),
#  (0.40894927126152303, 1.2007546262337916e-08),
#  (0.59754140900932651, 8.3740575918009054e-19),
#  (0.33280108050501522, 5.0024204786248152e-06),
#  (0.29922527359999956, 4.4949127072753381e-05),
#  (0.33280108050501522, 5.0024204786248152e-06),
#  (0.54100160836634514, 4.497189367053099e-15),
#  (0.3522917641457845, 1.2348765899793712e-06),
#  (0.44762843977484779, 2.972490954357487e-10),
#  (0.60426179813824532, 2.6890683905511132e-19),
#  (0.55100050312845272, 1.1064747509343735e-15),
#  (0.65812676582623386, 1.0343784476340843e-23)]
